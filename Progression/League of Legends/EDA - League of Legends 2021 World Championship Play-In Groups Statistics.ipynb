# %%
import numpy as np
import pandas as pd

import seaborn as sns

# %%
df = pd.read_csv('League of Legends 2021 World Championship Play-In Groups Statistics.csv')
df
# Out:
#     Team    Player Opponent Position Champion  Kills  Deaths  Assists  \
# 0    UOL      Boss       GS      Top  Camille      4       5        3
# 1     GS     Crazy      UOL      Top     Gwen      3       1        9
# 2    UOL  Ahahacik       GS   Jungle  Trundle      2       4        5
# 3     GS    Mojito      UOL   Jungle    Talon      5       4       10
# 4    UOL    Nomanz       GS      Mid  Leblanc      1       3        4
# ..   ...       ...      ...      ...      ...    ...     ...      ...
# 215  BYG     Maoan      UOL      Mid     Ryze      4       4        2
# 216  UOL  Argonavt      BYG      Adc    Senna      1       3        9
# 217  BYG     Doggo      UOL      Adc   Draven     10       2        4
# 218  UOL    Santas      BYG  Support   Wukong      0       4        7
# 219  BYG      Kino      UOL  Support    Rakan      0       5        9
#
#      Creep Score  Gold Earned  Champion Damage Share  Kill Participation  \
# ...

# %%
def desc_data(df):
    df_describe = []
    for i in df.columns: 
          df_describe.append([
          i,
          df[i].dtypes,
          df[i].isna().sum(),
          round((((df[i].isna().sum())/(len(df)))*100),2),
          df[i].nunique(),
          df[i].unique() 
      ])
    return pd.DataFrame(df_describe, columns=['column','type','nan','nan%','nunique','unique'])
display(desc_data(df))
print('Total duplicated data:',df.duplicated().sum())
# Out:
#                    column     type  nan  nan%  nunique  \
# 0                    Team   object    0   0.0       10
# 1                  Player   object    0   0.0       55
# 2                Opponent   object    0   0.0       10
# 3                Position   object    0   0.0        5
# 4                Champion   object    0   0.0       67
# 5                   Kills    int64    0   0.0       12
# 6                  Deaths    int64    0   0.0        8
# 7                 Assists    int64    0   0.0       18
# 8             Creep Score    int64    0   0.0      149
# 9             Gold Earned    int64    0   0.0      215
# 10  Champion Damage Share  float64    0   0.0       39
# 11     Kill Participation  float64    0   0.0       60
# 12           Wards Placed    int64    0   0.0       50
# 13        Wards Destroyed    int64    0   0.0       24
# 14      Ward Interactions    int64    0   0.0       56
# 15            Dragons For    int64    0   0.0        5
# ...

# %%
df.groupby(df.Team).sum()
# Out:
#       Kills  Deaths  Assists  Creep Score  Gold Earned  Champion Damage Share  \
# Team
# BYG      67      86      131         5349       289524                   4.98
# C9       84      67      187         5318       295207                   5.00
# DFM      82      38      172         5143       297348                   4.99
# GS       50      57      111         3779       210745                   4.01
# HLE      59      43      105         4605       245375                   4.01
# INF      34      69       72         3708       191887                   4.01
# LNG      69      18      124         4263       233701                   3.99
# PCE      57      62      128         3848       208114                   4.00
# RED      39      67       87         3674       200962                   4.01
# UOL      55      91      130         4388       248932                   5.00
#
#       Kill Participation  Wards Placed  Wards Destroyed  Ward Interactions  \
# Team
# ...

# %%
df.groupby(df.Team).sum().reset_index().Kills
# Out:
# 0    67
# 1    84
# 2    82
# 3    50
# 4    59
# 5    34
# 6    69
# 7    57
# 8    39
# 9    55
# Name: Kills, dtype: int64

# %%
sns.barplot(x=df.Team,y=df.Kills,data=df.groupby(df.Team).sum().reset_index().Kills)
# Out:
# <AxesSubplot:xlabel='Team', ylabel='Kills'>
