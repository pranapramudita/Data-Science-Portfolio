# %% [markdown]
# ## References
# 1. https://stackoverflow.com/questions/37428218/how-to-properly-apply-a-lambda-function-into-a-pandas-data-frame-column
# 1. https://stackoverflow.com/questions/44991438/lambda-including-if-elif-else

# %%
import pandas as pd

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df['Male'] = df.Sex.apply(lambda x: 1 if x == 'M' else 0)

# %%
df.ChestPainType.unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df['ChestPain'] = df.ChestPainType.apply(lambda x: 0 if x=='ATA' else(1 if x=='NAP' else(2 if x=='ASY' else 4)))

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Male  ChestPain
# ...

# %%
print(df.Sex.value_counts())
print(df.Male.value_counts())

print(df.ChestPainType.value_counts())
print(df.ChestPain.value_counts())
# Out:
# M    725
# F    193
# Name: Sex, dtype: int64
# 1    725
# 0    193
# Name: Male, dtype: int64
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64
# 2    496
# 1    203
# 0    173
# 4     46
# Name: ChestPain, dtype: int64
